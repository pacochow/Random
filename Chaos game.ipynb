# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm
import imageio
import os
from celluloid import Camera

# %%
def plot_shape(n_points):
    plt.plot([points[i][0] for i in range(n_points)], [points[i][1] for i in range(n_points)], linewidth = 10, color = 'tab:blue')
    plt.plot([points[0][0], points[n_points-1][0]], [points[0][1], points[n_points-1][1]], 
             linewidth = 10, color = 'tab:blue')
    

def compute_new_point(x, y, n_points):
    vertex = random.randint(0, n_points-1)

        
#     distance = (np.sqrt((y-points[vertex][1])**2 + (x-points[vertex][0])**2))
#     new_distance = distance/6
#     if y < points[vertex][1]:
#         theta = np.arccos(np.abs(y-points[vertex][1]) / distance)
#         y_distance = np.cos(theta) * new_distance
#         x_distance = np.sin(theta) * new_distance
#     else:
#         theta = np.arccos(np.abs(x-points[vertex][0]) / distance)
#         x_distance = np.cos(theta) * new_distance
#         y_distance = np.sin(theta) * new_distance


#     if x < points[vertex][0]:
#         x_distance = -x_distance
#     if y < points[vertex][1]:
#         y_distance = -y_distance
    
    
#     new_x = points[vertex][0] + x_distance
#     new_y = points[vertex][1] + y_distance
#     return new_x, new_y
    new_x = (points[vertex][0] + x)/2
    new_y = (points[vertex][1] + y)/2
    return new_x, new_y
        
iterations = 10000
n_point = 3
points = [(-20, 0), (0, 30), (20, 0)]
xs = []
ys = []
point = (random.uniform(-50, 50), random.uniform(-50, 50))
camera = Camera(plt.figure(figsize = (50, 50)))
plt.axis('off')

for t in tqdm(range(iterations)):
    plot_shape(n_point)
    point = compute_new_point(point[0], point[1], n_point)
    xs.append(point[0])
    ys.append(point[1])
plt.scatter(xs, ys, color = "tab:blue")
#     camera.snap()
# anim = camera.animate(blit = False, interval = 2)
# anim.save('Sierpinski.mp4')
# Out:
# 100%|████████████████████████████████████| 10000/10000 [00:11<00:00, 861.32it/s]

# %%
for i in range(4999):
    os.remove("Chaos_time_" + str(i) + ".png")

# %%
np.arccos(1.25)
# Out:
# /tmp/73161393.1.short.qc/ipykernel_140933/993799306.py:1: RuntimeWarning: invalid value encountered in arccos
#   np.arccos(1.25)
# nan

# %%
plt.plot((0, 0), (0, 3), (2, 4))

# %%
for i in
